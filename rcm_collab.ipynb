# %% [markdown]
# <a href="https://colab.research.google.com/github/ShiaHp/DACS4_RecSystem/blob/main/rcm_collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
ratings = pd.read_csv("/content/UserAnimeList.csv")
animes = pd.read_csv("/content/anime_cleaned.csv")
ratings = pd.merge(animes,ratings)
ratings
# Out:
#         anime_id                                              title  \
# 0          11013                                      Inu x Boku SS
# 1          11013                                      Inu x Boku SS
# 2          11013                                      Inu x Boku SS
# 3          11013                                      Inu x Boku SS
# 4          11013                                      Inu x Boku SS
# ...          ...                                                ...
# 962918     37405                            Dokidoki Little Ooyasan
# 962919     37886                        Wo Shi Jiang Xiaobai (2018)
# 962920     37255              Genki Genki Non-tan: Obake Mura Meiro
# 962921     35229                                Mr. Men Little Miss
# 962922     36315  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...
#
#                 username  my_score
# 0               karthiga         8
# 1       RedvelvetDaisuki         0
# 2              shuzzable         0
# ...

# %%
user_ratings = ratings .pivot_table(index = ['username'], columns = ['title'], values='my_score')
user_ratings.head()
# Out:
# title         "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi  \
# username
# #NAME?                                              NaN
# -Dementhia-                                         NaN
# -OoKaMi-                                            NaN
# -RedGoddess-                                        NaN
# -Shimizu-                                           NaN
#
# title         "Bungaku Shoujo" Memoire  "Bungaku Shoujo" Movie  \
# username
# #NAME?                             NaN                     NaN
# -Dementhia-                        NaN                     NaN
# -OoKaMi-                           NaN                     NaN
# -RedGoddess-                       NaN                     NaN
# -Shimizu-                          NaN                     NaN
#
# title         "Eikou Naki Tensai-tachi" Kara no Monogatari  "Eiyuu" Kaitai  \
# username
# #NAME?                                                 NaN             NaN
# ...

# %%
user_ratings = user_ratings.dropna(thresh = 10,axis = 1).fillna(0)
user_ratings

# %%
item_similarity_df = user_ratings.corr(method = "pearson")

# %%
def get_similar_movies(movie_name,user_rating):
  similar_score  = item_similarity_df[movie_name] * (user_rating - 2.5)
  similar_score = similar_score.sort_values(ascending=False)

  return similar_score

# %%
lover = [("Love Live! School Idol Project",10),("Naruto",2)]

similar_movies = pd.DataFrame()

for movie,rating in lover:
  similar_movies  = similar_movies.append(get_similar_movies(movie,rating), ignore_index = True)
  
similar_movies.head()
similar_movies.sum().sort_values(ascending=False)
# Out:
# Love Live! School Idol Project               7.486054
# Love Live! School Idol Project 2nd Season    6.011822
# Love Live! Sunshine!!                        4.193124
# Love Live! The School Idol Movie             4.038708
# Love Live! School Idol Project OVA           3.373860
#                                                ...
# Bleach: The Sealed Sword Frenzy             -0.340622
# Peace Maker Kurogane                        -0.349885
# X                                           -0.356038
# Samurai Deeper Kyou                         -0.364505
# Tenshi Kinryouku                            -0.394121
# Length: 5185, dtype: float64

# %% [markdown]
# # Mục mới
